# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from sklearn import preprocessing
import warnings
# %matplotlib inline 
# %config InlineBackend.figure_format = 'retina'
warnings.filterwarnings('ignore')

data = pd.read_csv("./Salary_Data.csv")
display(data)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = data.values[:, 0]
y = data.values[:, 1]
x = preprocessing.normalize([x]).T
y = preprocessing.normalize([y]).T
X = x
one = np.ones((30, 1))
X = np.concatenate([one, X], axis=1)

# %%
b = np.linalg.inv(X.T@X) @ X.T @ y
b
# Out:
# array([[0.05839456],
#        [0.70327706]])

# %%
np.linalg.inv(X)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-8-47889a8f1529> in <module>
# ----> 1 np.linalg.inv(X)
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in inv(a)
#     525     a, wrap = _makearray(a)
#     526     _assertRankAtLeast2(a)
# --> 527     _assertNdSquareness(a)
#     528     t, result_t = _commonType(a)
#     529
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/linalg/linalg.py in _assertNdSquareness(*arrays)
#     213         m, n = a.shape[-2:]
#     214         if m != n:
# --> 215             raise LinAlgError('Last 2 dimensions of the array must be square')
#     216
#     217 def _assertFinite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
X.T @ X
# Out:
# array([[30.        ,  4.84926515],
#        [ 4.84926515,  1.        ]])
